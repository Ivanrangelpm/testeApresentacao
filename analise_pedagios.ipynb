# %%
import pandas as pd

# %%
seg = pd.read_csv("csv/tagTom2024-12-02_12-39-51.csv")
terca = pd.read_csv("csv/tagTom2024-12-03_12-49-03.csv")
quarta = pd.read_csv("csv/tagTom2024-12-04_19-40-25.csv")
quinta = pd.read_csv("csv/tagTom2024-12-05_12-07-43.csv")
sexta = pd.read_csv("csv/tagTom2024-12-06_22-56-23.csv")
sabado = pd.read_csv("csv/tagTom2024-12-07_15-16-29.csv")
domingo = pd.read_csv("csv/tagTom2024-12-08_15-30-14.csv")

# %%
seg['Data'] = '2024-12-02'
terca['Data'] = '2024-12-03'
quarta['Data'] = '2024-12-04'
quinta['Data'] = '2024-12-05'
sexta['Data'] = '2024-12-06'
sabado['Data'] = '2024-12-07'
domingo['Data'] = '2024-12-08'

# %%
df_unificado = pd.concat([seg, terca, quarta, quinta, sexta, sabado, domingo], ignore_index=True)

df_unificado
# Out:
#       Unnamed: 0         concessionaria                praca_de_pedagio  \
# 0              0  AUTOPISTA FERNÃO DIAS  1 Norte - Defasada (Mairiporã)
# 1              1  AUTOPISTA FERNÃO DIAS             1 Norte (Mairiporã)
# 2              2  AUTOPISTA FERNÃO DIAS               1 Sul (Mairiporã)
# 3              3  AUTOPISTA FERNÃO DIAS                      2 (Vargem)
# 4              4  AUTOPISTA FERNÃO DIAS                      3 (Cambuí)
# ...          ...                    ...                             ...
# 1255         175                VIA SUL                     P5-Paverama
# 1256         176                VIA SUL              P6-Fontoura Xavier
# 1257         177                VIA SUL                P7-Victor Graeff
# 1258         178                VIA SUL    P2-Santo Antônio da Patrulha
# 1259         179                VIA SUL                     P3-Gravatai
#
#      rodovia  uf                  municipio            localizacao  \
# ...

# %%
dfs = [seg, terca, quarta, quinta, sexta, sabado, domingo]

# %%
listaMedias= []

for df in dfs:
    listaMedias.append(df['nivelTransito'].mean())
    
    
print(listaMedias)
# Out:
# [22.0, 20.0, 41.0, 37.0, 82.0, 75.0, 79.0]
